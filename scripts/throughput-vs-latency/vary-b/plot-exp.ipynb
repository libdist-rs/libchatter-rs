# %%
# Build a ping percentile plot

import matplotlib.pyplot as plt
from numpy import percentile
from csv import reader
import math

ROOT="/run/media/haxolotl/Backup/GitRoot/libapollo-rust"

# %%
shs_b100_w = []
shs_b100_lat = []
shs_b100_tput = []
apl_b100_w = []
apl_b100_lat = []
apl_b100_tput = []

shs_b400_w = []
shs_b400_lat = []
shs_b400_tput = []
apl_b400_w = []
apl_b400_lat = []
apl_b400_tput = []

shs_b800_w = []
shs_b800_lat = []
shs_b800_tput = []
apl_b800_w = []
apl_b800_lat = []
apl_b800_tput = []

shs_b2000_w = []
shs_b2000_lat = []
shs_b2000_tput = []
apl_b2000_w = []
apl_b2000_lat = []
apl_b2000_tput = []

BlockSize=100
Protocol="synchs"
with open(f"{ROOT}/data/Jan17/c5/vary-b/b{BlockSize}-{Protocol}-run-cleaned.csv") as f:
    rdr = reader(f)
    for row in rdr:
        shs_b100_w.append(float(row[0])/1000)
        shs_b100_tput.append(float(row[1])/1000)
        shs_b100_lat.append(float(row[2]))

BlockSize=400
with open(f"{ROOT}/data/Jan17/c5/vary-b/b{BlockSize}-{Protocol}-run-cleaned.csv") as f:
    rdr = reader(f)
    for row in rdr:
        shs_b400_w.append(float(row[0])/1000)
        shs_b400_tput.append(float(row[1])/1000)
        shs_b400_lat.append(float(row[2]))

BlockSize=800
with open(f"{ROOT}/data/Jan17/c5/vary-b/b{BlockSize}-{Protocol}-run-cleaned.csv") as f:
    rdr = reader(f)
    for row in rdr:
        shs_b800_w.append(float(row[0])/1000)
        shs_b800_tput.append(float(row[1])/1000)
        shs_b800_lat.append(float(row[2]))

BlockSize=2000
with open(f"{ROOT}/data/Jan17/c5/vary-b/b{BlockSize}-{Protocol}-run-cleaned.csv") as f:
    rdr = reader(f)
    for row in rdr:
        shs_b2000_w.append(float(row[0])/1000)
        shs_b2000_tput.append(float(row[1])/1000)
        shs_b2000_lat.append(float(row[2]))


BlockSize=100
Protocol="apollo"
with open(f"{ROOT}/data/Jan17/c5/vary-b/b{BlockSize}-{Protocol}-run-cleaned.csv") as f:
    rdr = reader(f)
    for row in rdr:
        apl_b100_w.append(float(row[0])/1000)
        apl_b100_tput.append(float(row[1])/1000)
        apl_b100_lat.append(float(row[2]))

BlockSize=400
with open(f"{ROOT}/data/Jan17/c5/vary-b/b{BlockSize}-{Protocol}-run-cleaned.csv") as f:
    rdr = reader(f)
    for row in rdr:
        apl_b400_w.append(float(row[0])/1000)
        apl_b400_tput.append(float(row[1])/1000)
        apl_b400_lat.append(float(row[2]))

BlockSize=800
with open(f"{ROOT}/data/Jan17/c5/vary-b/b{BlockSize}-{Protocol}-run-cleaned.csv") as f:
    rdr = reader(f)
    for row in rdr:
        apl_b800_w.append(float(row[0])/1000)
        apl_b800_tput.append(float(row[1])/1000)
        apl_b800_lat.append(float(row[2]))

BlockSize=2000
with open(f"{ROOT}/data/Jan17/c5/vary-b/b{BlockSize}-{Protocol}-run-cleaned.csv") as f:
    rdr = reader(f)
    for row in rdr:
        apl_b2000_w.append(float(row[0])/1000)
        apl_b2000_tput.append(float(row[1])/1000)
        apl_b2000_lat.append(float(row[2]))

# %%
plt.rc('text',usetex=True)

plt.rcParams["figure.figsize"] =(6.6, 4)
plt.rcParams.update({'font.size': 13})

plt.plot(shs_b100_tput,shs_b100_lat, label="Sync HotStuff (b100)", linestyle='--', marker='+')
plt.plot(apl_b100_tput,apl_b100_lat, label="Apollo (b100)", linestyle='--', marker='o')

plt.plot(shs_b400_tput,shs_b400_lat, label="Sync HotStuff (b400)", linestyle='--', marker='+')
plt.plot(apl_b400_tput,apl_b400_lat, label="Apollo (b400)", linestyle='--', marker='o')

plt.plot(shs_b800_tput,shs_b800_lat, label="Sync HotStuff (b800)", linestyle='--', marker='+')
plt.plot(apl_b800_tput,apl_b800_lat, label="Apollo (b800)", linestyle='--', marker='o')

plt.plot(shs_b2000_tput,shs_b2000_lat, label="Sync HotStuff (b2000)", linestyle='--', marker='+')
plt.plot(apl_b2000_tput,apl_b2000_lat, label="Apollo (b2000)", linestyle='--', marker='o')

plt.legend()
plt.xlabel("Response Rate (in Kops/s)")
plt.ylabel("Latency (in ms)")
# plt.show()
# plt.xticks(log_points)
plt.savefig("Tput-vs-latency-for-diff-b.pdf", bbox_inches="tight")

# %%
plt.rc('text',usetex=True)

# plt.rcParams["figure.figsize"] =(7, 4.3)
plt.rcParams.update({'font.size': 13})

plt.plot(shs_b100_w,shs_b100_lat, label="Sync HotStuff (b100)", linestyle='--', marker='+')
plt.plot(apl_b100_w,apl_b100_lat, label="Apollo (b100)", linestyle='--', marker='o')

plt.plot(shs_b400_w,shs_b400_lat, label="Sync HotStuff (b400)", linestyle='--', marker='+')
plt.plot(apl_b400_w,apl_b400_lat, label="Apollo (b400)", linestyle='--', marker='o')

plt.plot(shs_b800_w,shs_b800_lat, label="Sync HotStuff (b800)", linestyle='--', marker='+')
plt.plot(apl_b800_w,apl_b800_lat, label="Apollo (b800)", linestyle='--', marker='o')

plt.plot(shs_b2000_w,shs_b2000_lat, label="Sync HotStuff (b2000)", linestyle='--', marker='+')
plt.plot(apl_b2000_w,apl_b2000_lat, label="Apollo (b2000)", linestyle='--', marker='o')

plt.legend()
plt.xlabel("Offered Load $w$ (in Kops)")
plt.ylabel("Latency (in ms)")
# plt.show()
# plt.xticks(log_points)
plt.savefig("Latency-vs-w-for-diff-b.pdf", bbox_inches="tight")

# %%
plt.rc('text',usetex=True)

# plt.rcParams["figure.figsize"] =(6.6, 4)
plt.rcParams.update({'font.size': 13})

plt.plot(shs_b100_w,shs_b100_tput, label="Sync HotStuff (b100)", linestyle='--', marker='+')
plt.plot(apl_b100_w,apl_b100_tput, label="Apollo (b100)", linestyle='--', marker='o')

plt.plot(shs_b400_w,shs_b400_tput, label="Sync HotStuff (b400)", linestyle='--', marker='+')
plt.plot(apl_b400_w,apl_b400_tput, label="Apollo (b400)", linestyle='--', marker='o')

plt.plot(shs_b800_w,shs_b800_tput, label="Sync HotStuff (b800)", linestyle='--', marker='+')
plt.plot(apl_b800_w,apl_b800_tput, label="Apollo (b800)", linestyle='--', marker='o')

plt.plot(shs_b2000_w,shs_b2000_tput, label="Sync HotStuff (b2000)", linestyle='--', marker='+')
plt.plot(apl_b2000_w,apl_b2000_tput, label="Apollo (b2000)", linestyle='--', marker='o')

plt.legend()
plt.xlabel("Offered Load $w$ (in Kops)")
plt.ylabel("Response Rate (in Kops/s)")
# plt.show()
# plt.xticks(log_points)
plt.savefig("Tput-vs-w-for-diff-b.pdf", bbox_inches="tight")
